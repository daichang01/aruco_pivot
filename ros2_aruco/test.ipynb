# %%
import cv2
# 检查是否可以访问 ArUco 模块
if hasattr(cv2.aruco, 'detectMarkers'):
    print("Aruco module is available")
else:
    print("Aruco module is not available")
# Out:
# Aruco module is not available
